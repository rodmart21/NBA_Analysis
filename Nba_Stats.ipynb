# %% [markdown]
# <a href="https://colab.research.google.com/github/rodmart21/Sport_stats/blob/main/Nba_Stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
shot = pd.read_csv("/shot log GSW.csv")
pd.set_option('display.max_columns', 100)
print(shot.columns.tolist())
shot.describe()
# Out:
# ['self previous shot', 'player position', 'home game', 'location x', 'opponent previous shot', 'home team', 'shot type', 'points', 'away team', 'location y', 'time', 'date', 'shoot player', 'time from last shot', 'quarter', 'current shot outcome']
#         location x       points   location y  time from last shot      quarter
# count  7139.000000  7140.000000  7139.000000          6808.000000  7140.000000
# mean    474.527945     2.358683   246.073680            32.646445     2.458964
# std     337.738770     0.479648   114.454533            19.466990     1.129206
# min      22.000000     2.000000     2.000000             0.000000     1.000000
# 25%     113.000000     2.000000   187.000000            22.000000     1.000000
# 50%     607.000000     2.000000   250.000000            30.000000     2.000000
# 75%     837.000000     3.000000   298.000000            40.000000     3.000000
# max     928.000000     3.000000   498.000000           179.000000     6.000000

# %%
x = shot['location x']
y = shot['location y']
plt.scatter(x,y, s=.005,c='r', marker= '.')

# %%
plt.figure(figsize=(94/6,50/6))
plt.scatter(x,y, s=.1,c='r', marker= '.')
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='.5', color='black')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='red')

# %%
shot['halfcourt_x'] =np.where(shot['location x'] < 933/2, 933 - shot['location x'],shot['location x'])
shot['halfcourt_y'] =np.where(shot['location x'] < 933/2, 500 - shot['location y'],shot['location y'])
shot.describe()
# Out:
#         location x       points   location y  time from last shot  \
# count  7139.000000  7140.000000  7139.000000          6808.000000
# mean    474.527945     2.358683   246.073680            32.646445
# std     337.738770     0.479648   114.454533            19.466990
# min      22.000000     2.000000     2.000000             0.000000
# 25%     113.000000     2.000000   187.000000            22.000000
# 50%     607.000000     2.000000   250.000000            30.000000
# 75%     837.000000     3.000000   298.000000            40.000000
# max     928.000000     3.000000   498.000000           179.000000
#
#            quarter  halfcourt_x  halfcourt_y
# count  7140.000000  7139.000000  7139.000000
# mean      2.458964   791.186161   245.802213
# std       1.129206    93.252679   114.444897
# min       1.000000   474.000000     4.000000
# 25%       1.000000   711.000000   181.000000
# 50%       2.000000   828.000000   250.000000
# 75%       3.000000   875.000000   289.500000
# max       6.000000   928.000000   498.000000

# %%
hx = shot['halfcourt_x']
hy = shot['halfcourt_y']
plt.figure(figsize=(94/12,50/6))
plt.scatter(hx,hy, s=.01,c='r', marker= '.')
plt.minorticks_on()
plt.grid(which='major', linestyle='-', linewidth='.5', color='black')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='red')
plt.title("Shots", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Shots')

# %%
shot
# Out:
#      self previous shot player position home game  location x  \
# 0                   NaN              PF       Yes       244.0
# 1                MISSED              SF       Yes       197.0
# 2                SCORED              SG       Yes        74.0
# 3                MISSED              PF       Yes        54.0
# 4                MISSED              PG       Yes       308.0
# ...                 ...             ...       ...         ...
# 7135             MISSED              PF       Yes       888.0
# 7136             SCORED              SG       Yes       617.0
# 7137             MISSED               C       Yes       882.0
# 7138             MISSED               C       Yes       888.0
# 7139             MISSED               C       Yes       794.0
#
#      opponent previous shot home team              shot type  points  \
# 0                    MISSED       GSW              Jump Shot       3
# 1                    SCORED       GSW    Turnaround Fadeaway       2
# 2                    SCORED       GSW  Running Reverse Layup       2
# 3                    MISSED       GSW     Cutting Layup Shot       2
# 4                    MISSED       GSW              Jump Shot       3
# ...                     ...       ...                    ...     ...
# 7135                 MISSED       GSW           Running Dunk       2
# 7136                 MISSED       GSW              Jump Shot       3
# 7137                 MISSED       GSW   Turnaround Jump Shot       2
# 7138                 SCORED       GSW        Fadeaway Jumper       2
# 7139                 SCORED       GSW           Putback Dunk       2
#
#      away team  location y   time        date          shoot player  \
# 0          SAS        92.0   0:39  2016-10-25        Draymond Green
# 1          SAS       244.0   1:05  2016-10-25          Kevin Durant
# 2          SAS       251.0   1:40  2016-10-25         Klay Thompson
# 3          SAS       231.0   2:32  2016-10-25        Draymond Green
# 4          SAS       380.0   2:58  2016-10-25         Stephen Curry
# ...        ...         ...    ...         ...                   ...
# 7135       LAL       250.0   9:03  2017-04-12  James Michael McAdoo
# 7136       LAL       158.0   9:45  2017-04-12             Ian Clark
# 7137       LAL       365.0  10:26  2017-04-12          JaVale McGee
# 7138       LAL       250.0  11:24  2017-04-12          JaVale McGee
# 7139       LAL       272.0  11:24  2017-04-12          JaVale McGee
#
#       time from last shot  quarter current shot outcome  halfcourt_x  \
# 0                     NaN        1               MISSED        689.0
# 1                    26.0        1               SCORED        736.0
# 2                    35.0        1               MISSED        859.0
# 3                    52.0        1               MISSED        879.0
# 4                    26.0        1               MISSED        625.0
# ...                   ...      ...                  ...          ...
# 7135                 13.0        4               SCORED        888.0
# 7136                 42.0        4               MISSED        617.0
# 7137                 41.0        4               MISSED        882.0
# 7138                 58.0        4               MISSED        888.0
# 7139                  0.0        4               SCORED        794.0
#
#       halfcourt_y
# 0           408.0
# 1           256.0
# 2           249.0
# 3           269.0
# 4           120.0
# ...           ...
# 7135        250.0
# 7136        158.0
# 7137        365.0
# 7138        250.0
# 7139        272.0
#
# [7140 rows x 18 columns]

# %%
# Comparing players

# We use a pivot table here to list players by shots

playersn = shot.groupby('shoot player')['current shot outcome'].describe().reset_index()
playersn.sort_values(by = 'count', ascending = False)
# Out:
#             shoot player count unique     top freq
# 15         Stephen Curry  1444      3  MISSED  713
# 11         Klay Thompson  1376      3  MISSED  689
# 9           Kevin Durant  1026      3  SCORED  551
# 5         Draymond Green   651      3  MISSED  339
# 6              Ian Clark   433      3  SCORED  211
# 1         Andre Iguodala   415      3  SCORED  219
# 7           JaVale McGee   319      3  SCORED  208
# 14      Shaun Livingston   314      3  SCORED  173
# 16         Zaza Pachulia   306      3  SCORED  164
# 4             David West   252      3  SCORED  135
# 13         Patrick McCaw   245      3  MISSED  121
# 8   James Michael McAdoo   118      3  SCORED   62
# 10          Kevon Looney   107      3  SCORED   56
# 12           Matt Barnes    90      3  MISSED   50
# 3           Damian Jones    16      3  SCORED    8
# 2          Briante Weber    14      3  MISSED    8
# 0       Anderson Varejao    14      2  MISSED    9

# %%
Curry = shot[shot['shoot player']=='Stephen Curry']
Curry
# Out:
#      self previous shot player position home game  location x  \
# 4                MISSED              PG       Yes       308.0
# 5                MISSED              PG       Yes       225.0
# 14               SCORED              PG       Yes       280.0
# 15               MISSED              PG       Yes       192.0
# 27               MISSED              PG       Yes       318.0
# ...                 ...             ...       ...         ...
# 7108             MISSED              PG       Yes       704.0
# 7112             SCORED              PG       Yes       665.0
# 7115             SCORED              PG       Yes       881.0
# 7116             SCORED              PG       Yes       866.0
# 7118             MISSED              PG       Yes       622.0
#
#      opponent previous shot home team              shot type  points  \
# 4                    MISSED       GSW              Jump Shot       3
# 5                    SCORED       GSW    Step Back Jump Shot       3
# 14                   SCORED       GSW              Jump Shot       3
# 15                   SCORED       GSW              Jump Shot       2
# 27                   MISSED       GSW              Jump Shot       3
# ...                     ...       ...                    ...     ...
# 7108                 SCORED       GSW              Jump Shot       3
# 7112                 SCORED       GSW       Pullup Jump Shot       3
# 7115                 MISSED       GSW  Running Reverse Layup       2
# 7116                BLOCKED       GSW              Jump Shot       3
# 7118                 SCORED       GSW              Jump Shot       3
#
#      away team  location y   time        date   shoot player  \
# 4          SAS       380.0   2:58  2016-10-25  Stephen Curry
# 5          SAS       439.0   3:54  2016-10-25  Stephen Curry
# 14         SAS       409.0   9:37  2016-10-25  Stephen Curry
# 15         SAS       413.0   9:59  2016-10-25  Stephen Curry
# 27         SAS       241.0   5:13  2016-10-25  Stephen Curry
# ...        ...         ...    ...         ...            ...
# 7108       LAL        66.0   6:37  2017-04-12  Stephen Curry
# 7112       LAL       128.0   9:09  2017-04-12  Stephen Curry
# 7115       LAL       266.0  10:20  2017-04-12  Stephen Curry
# 7116       LAL       482.0  10:55  2017-04-12  Stephen Curry
# 7118       LAL       251.0  11:35  2017-04-12  Stephen Curry
#
#       time from last shot  quarter current shot outcome  halfcourt_x  \
# 4                    26.0        1               MISSED        625.0
# 5                    56.0        1               SCORED        708.0
# 14                   35.0        1               MISSED        653.0
# 15                   22.0        1               MISSED        741.0
# 27                   35.0        2               SCORED        615.0
# ...                   ...      ...                  ...          ...
# 7108                 65.0        3               SCORED        704.0
# 7112                 51.0        3               MISSED        665.0
# 7115                 13.0        3               SCORED        881.0
# 7116                 35.0        3               MISSED        866.0
# 7118                 11.0        3               MISSED        622.0
#
#       halfcourt_y
# 4           120.0
# 5            61.0
# 14           91.0
# 15           87.0
# 27          259.0
# ...           ...
# 7108         66.0
# 7112        128.0
# 7115        266.0
# 7116        482.0
# 7118        251.0
#
# [1444 rows x 18 columns]

# %%
hxL = Curry['halfcourt_x']
hyL = Curry['halfcourt_y']
colors = np.where(LeBron['current shot outcome']=='SCORED','r',np.where(Curry['current shot outcome']=='MISSED','b','g'))
plt.figure(figsize=(94/12,50/6))
plt.scatter(hxL,hyL, s=10, c= colors, marker= '.')
plt.grid(True)
plt.title("Don Stephen", fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Don Stephen')

# %% [markdown]
# ### Esto para tiros desde dentro de la pintura

# %%
# Define the subset

rect1 = shot[(((shot['location x']>700) & (shot['location x']<900)) & \
                 ((shot['location y'] > 200) & (shot['location y'] < 300)))]
rect1
# Out:
#      self previous shot player position home game  location x  \
# 19               MISSED              PG       Yes       738.0
# 42               SCORED               C       Yes       882.0
# 43               SCORED              SF       Yes       824.0
# 44               MISSED              PF       Yes       882.0
# 45               SCORED              SF       Yes       866.0
# ...                 ...             ...       ...         ...
# 7131             SCORED               G       Yes       886.0
# 7133             MISSED               C       Yes       888.0
# 7135             MISSED              PF       Yes       888.0
# 7138             MISSED               C       Yes       888.0
# 7139             MISSED               C       Yes       794.0
#
#      opponent previous shot home team                   shot type  points  \
# 19                   SCORED       GSW                   Jump Shot       3
# 42                   SCORED       GSW          Cutting Layup Shot       2
# 43                   MISSED       GSW  Driving Floating Jump Shot       2
# 44                   MISSED       GSW               Putback Layup       2
# 45                   MISSED       GSW               Reverse Layup       2
# ...                     ...       ...                         ...     ...
# 7131                 SCORED       GSW               Driving Layup       2
# 7133                 MISSED       GSW                Driving Dunk       2
# 7135                 MISSED       GSW                Running Dunk       2
# 7138                 SCORED       GSW             Fadeaway Jumper       2
# 7139                 SCORED       GSW                Putback Dunk       2
#
#      away team  location y   time        date          shoot player  \
# 19         SAS       245.0  12:00  2016-10-25      Shaun Livingston
# 42         SAS       238.0   0:14  2016-10-25         Zaza Pachulia
# 43         SAS       284.0   0:42  2016-10-25          Kevin Durant
# 44         SAS       248.0   0:44  2016-10-25        Draymond Green
# 45         SAS       248.0   1:19  2016-10-25          Kevin Durant
# ...        ...         ...    ...         ...                   ...
# 7131       LAL       244.0   7:24  2017-04-12         Patrick McCaw
# 7133       LAL       250.0   8:11  2017-04-12          Damian Jones
# 7135       LAL       250.0   9:03  2017-04-12  James Michael McAdoo
# 7138       LAL       250.0  11:24  2017-04-12          JaVale McGee
# 7139       LAL       272.0  11:24  2017-04-12          JaVale McGee
#
#       time from last shot  quarter current shot outcome  halfcourt_x  \
# 19                   31.0        1               MISSED        738.0
# 42                    NaN        3               SCORED        882.0
# 43                   28.0        3               MISSED        824.0
# 44                    2.0        3               SCORED        882.0
# 45                   35.0        3               SCORED        866.0
# ...                   ...      ...                  ...          ...
# 7131                 58.0        4               SCORED        886.0
# 7133                 19.0        4               SCORED        888.0
# 7135                 13.0        4               SCORED        888.0
# 7138                 58.0        4               MISSED        888.0
# 7139                  0.0        4               SCORED        794.0
#
#       halfcourt_y
# 19          245.0
# 42          238.0
# 43          284.0
# 44          248.0
# 45          248.0
# ...           ...
# 7131        244.0
# 7133        250.0
# 7135        250.0
# 7138        250.0
# 7139        272.0
#
# [1513 rows x 18 columns]

# %%
xr = rect1['location x']
yr = rect1['location y']
colors = np.where(rect1['current shot outcome']=='SCORED','r',np.where(rect1['current shot outcome']=='MISSED','b','g'))
plt.figure(figsize=(94/6,50/6))
plt.scatter(xr,yr, s=50, c= colors, marker= '.')
plt.grid(True)
